# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import matplotlib.pyplot as plt

sample_df=pd.read_csv("r15.csv")

# %%
training_points=sample_df[["col1","col2"]]
training_labels= sample_df["target"]

agglo= AgglomerativeClustering(n_clusters=15).fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np
import scipy.cluster.hierarchy as shc
X=np.array([[2,10],[2,5],[8,4],[5,8],[7,5],[6,4],[1,2],[4,9]])
dend=shc.dendrogram(shc.linkage(X, method='average'))

# %%
agglo= AgglomerativeClustering(n_clusters=15,linkage='single').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=15,linkage='complete').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=15,linkage='average').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import matplotlib.pyplot as plt

sample_df=pd.read_csv("spiral.csv")

training_points=sample_df[["col1","col2"]]
training_labels= sample_df["target"]

agglo= AgglomerativeClustering(n_clusters=3).fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import matplotlib.pyplot as plt

sample_df=pd.read_csv("Iris.csv")


agglo= AgglomerativeClustering(n_clusters=3).fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='single').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='average').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='complete').fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import matplotlib.pyplot as plt

sample_df=pd.read_csv("Iris.csv")


agglo= AgglomerativeClustering(n_clusters=3).fit(training_points)

plt.scatter(training_points["col1"],training_points["col2"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import matplotlib.pyplot as plt

sample_df=pd.read_csv("Iris.csv")

training_points=sample_df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
training_labels= sample_df["Species"]

agglo= AgglomerativeClustering(n_clusters=3).fit(training_points)

plt.scatter(training_points["SepalLengthCm"],training_points["SepalWidthCm"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='complete').fit(training_points)

plt.scatter(training_points["SepalLengthCm"],training_points["PetalLengthCm"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='single').fit(training_points)

plt.scatter(training_points["SepalLengthCm"],training_points["PetalLengthCm"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
agglo= AgglomerativeClustering(n_clusters=3,linkage='average').fit(training_points)

plt.scatter(training_points["SepalLengthCm"],training_points["PetalLengthCm"],c=agglo.labels_,cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np
import scipy.cluster.hierarchy as shc
sample_df=pd.read_csv("Iris.csv")
training_points=sample_df.drop(columns=["Species","Id"])

X = np.array([[2, 10], [2, 5], [8, 4],[5, 8], [7, 5], [6, 4], [1, 2], [4, 9]])

dend=shc.dendrogram(shc.linkage(training_points, method='average'))

# %%
from sklearn.cluster import KMeans
import numpy as np
import scipy.cluster.hierarchy as shc
sample_df=pd.read_csv("Iris.csv")
training_points=sample_df.drop(columns=["Species","Id"])

X = np.array([[2, 10], [2, 5], [8, 4],[5, 8], [7, 5], [6, 4], [1, 2], [4, 9]])

dend=shc.dendrogram(shc.linkage(training_points, method='single'))

# %%
from sklearn.cluster import KMeans
import numpy as np
import scipy.cluster.hierarchy as shc
sample_df=pd.read_csv("Iris.csv")
training_points=sample_df.drop(columns=["Species","Id"])

X = np.array([[2, 10], [2, 5], [8, 4],[5, 8], [7, 5], [6, 4], [1, 2], [4, 9]])

dend=shc.dendrogram(shc.linkage(training_points, method='complete'))

# %%
from sklearn.cluster import DBSCAN
import pandas as pd
import matplotlib.pyplot as plt

sample_df = pd.read_csv("r15.csv")

training_points = sample_df[["col1", "col2"]]
training_labels = sample_df["target"]

dbscan = DBSCAN(eps=0.6, min_samples=10).fit(training_points)

plt.scatter(training_points["col1"], training_points["col2"], c=dbscan.labels_,
	cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import OPTICS
import pandas as pd
import matplotlib.pyplot as plt

sample_df = pd.read_csv("flame.csv")

training_points = sample_df[["col1", "col2"]]
training_labels = sample_df["target"]

optics = OPTICS( min_samples=8).fit(training_points)

plt.scatter(training_points["col1"], training_points["col2"], c=optics.labels_,
	cmap='rainbow')

plt.show()

# %%
from sklearn.cluster import OPTICS
import pandas as pd
import matplotlib.pyplot as plt

sample_df = pd.read_csv("flame.csv")

training_points = sample_df[["col1", "col2"]]
training_labels = sample_df["target"]


plt.scatter(training_points["col1"], training_points["col2"], c=optics.labels_,
	cmap='rainbow')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-1972ee1e6827> in <module>()
#       9
#      10
# ---> 11 plt.scatter(training_points["col1"], training_points["col2"], c=optics.labels_,
#      12 	cmap='rainbow')
#      13
#
# NameError: name 'optics' is not defined

# %%
# 성능평가
from sklearn.cluster import OPTICS
import pandas as pd
from sklearn.metrics.cluster import adjusted_rand_score

sample_df = pd.read_csv("flame.csv")

training_points = sample_df[["col1", "col2"]]
training_labels = sample_df["target"]


arc = adjusted_rand_score(training_labels, dbscan.labels_)

print(arc)
# Out:
# 0.9714854388216635

# %%
# 5개 선택 정확도 비교
